# %%
#learndataa learndataa learndataa learndataa learndataa learndataa learndataa learndataa learndataa

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### For Beginners: 11. Plots in Python using Matplotlib

# %% [markdown]
# #### Total questions sets: 4
# #### Estimated time required: upto 120 minutes or more (Please take your time to understand and solve the questions.)

# %% [markdown]
# [Notes:
# - Answers may be typed after the line "#-------#" in each cell. Additional cells may be created if needed.
# - The estimated time required to complete the exercise may vary depending on your prior knowledge.
# - Answers to the questions are posted at the end of this worksheet. However, to help you learn, it is suggested that you to try to answer the questions yourself before looking at the answers.
# ]

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Question 0:
#
# - In a new cell, create a line plot using x, y
# - In a new cell, create a bar plot using xb, yb
# - In a new cell, create a scatter plot using xs, ys
# - In a new cell, create a histogram using xh
#
# Note: Add labels to both x-axis, y-axis and the plot title

# %%
# Data for line plot
x = np.linspace(0,100, 50,1)
y = x**2

# Data for bar plot
xb = ['A', 'B', 'C', 'D', 'E']
yb = [1000, 5000, 2345, 4905, 200]

# Data for scatter plot
xs = np.linspace(0,50,50)
ys = np.random.random(50)

# Data for histogram
xh = np.random.normal(0,0.25,500)

# %%
# ------- type the answer below this line ------- #

# %%
# ------- type the answer below this line ------- #

# %%
# ------- type the answer below this line ------- #

# %%
# ------- type the answer below this line ------- #

# %% [markdown]
# ### Question 1:
#
# #### Story
# A new movie 'Thonpy' was released this week. It was a box office hit!!! Entire crew of the movie studio are very happy and would like to visualize their success in the world.
#
# Let's help them out!
#
# #### Request:
# - In a new cell, create a bar plot for movie revenue by country
#         - Hint: To rotate the x-axis labels by 90 degrees type:
#         plt.xticks(rotation=90)
# - In a new cell, combine customer ratings for all countries into a single array and plot histogram
#         - Hint-1: Combine the five 6x7 arrays into a single array of shape 30x7. Store this in variable 'ratings'.
#         - Hint-2: Then use np.ndarray.flatten(ratings) to flattent the array to (210,) to plot histogram
# - In new cell, Create a heatmap for customer ratings in each country.
#         - Hint-1: To plot heatmap:
#         plt.imshow(f_rating)
#         plt.colorbar()
#
#         - Hint-2: Use subplot
#         fig = plt.figure(figsize=(15,5))
#         plt.subplot(2,3,1)
#         ... 1st figure here ...
#         plt.subplot(2,3,2)
#         ... 2nd figure here ...
#         .
#         .
#         . and so on ...
#         - Hint-4: For spacing between subplots use:
#         plt.tight_layout()
#         - Hint-3: Make sure the x,y axes and the plot title are labeled
#
#
# - In a new cell, plot the average customer rating by country
#         - Hint-1: To get an average of f_rating: np.mean(f_rating)
#         - Hint-2: Store the average rating for each country in a list 'avg_rating'
#         - Hint-3: Then use plt.bar(x,y) to plot 'countries' and the calculated average rating
#
#
# <b>Important:</b> For each plot make sure x-axis, y-axis are labeled and a title is added to each plot
#
# [Note: Create new variables of your choice as needed.]

# %%
# Countries where the movie was released
countries = ['Floweria', 'Public of Land', 'Restandris', 'Provinces of Oceania', 'The Kingdom of Skydome']

# Revenue in millions
movie_revenue = [1000, 3577, 469, 1212, 9879]

# Customer rating 1(low) --> 5(high)
# ------ Floweria --------
f_theaters = ['sunglow','superpetal','soilplant','funlily','actionacactus','rosered']
f_rating = np.array([
    [4.7, 5.0, 4.9, 4.8, 4.7, 5.0, 4.6], # SunGlow
    [3.6, 3.3, 3.2, 3.0, 3.4, 4.0, 3.2], # SuperPetal
    [4.0, 5.0, 5.0, 4.8, 4.7, 5.0, 4.6], # SoilPlant
    [4.0, 3.9, 3.8, 3.8, 3.7, 4.1, 3.4], # FunLily
    [4.4, 4.5, 4.4, 4.6, 4.5, 4.8, 4.3], # ActionCactus
    [1.4, 2.5, 1.5, 2.1, 1.7, 2.5, 1.0], # RoseRed
 #. Mon.  Tue. Wed. Thu. Fri. Sat. Sun.   
])

# ------ Public of Land --------
pol_theaters = ['landing','sandland','laland','stonemuse','rapland','tresly']
pol_rating = np.array([
    [4.4, 4.9, 4.6, 4.9, 4.1, 4.3, 4.1], # LandIng
    [4.7, 5. , 4.9, 4.3, 4.8, 4.7, 4.6], # SandLand
    [4.6, 4.3, 4.9, 4.1, 4.7, 4.9, 4.7], # LaLand
    [4.6, 4.3, 4.2, 4.4, 4.3, 4.6, 4.6], # StoneMuse
    [4.5, 5. , 4.2, 4.2, 4.3, 4.1, 4.6], # RapLand
    [4.5, 4.6, 4.4, 4.2, 4.6, 4.6, 4.1], # Tresly
 #. Mon.  Tue. Wed. Thu. Fri. Sat. Sun.   
])


# ------ Restandris --------
r_theaters = ['restmovie','andmovie','movielax','tranbie','festive','happenmovie']
r_rating = np.array([
    [3.1, 3.4, 3.8, 3. , 3.6, 3.9, 3.8], # RestMovie
    [3.3, 3.8, 3.9, 3.9, 3.5, 3.8, 3.3], # AndMovie
    [3.5, 4. , 3.9, 3.1, 3.7, 3.2, 3.3], # Movielax
    [3.9, 3.4, 3.3, 3.2, 3.6, 3.8, 3.2], # Tranbie
    [3.3, 2.5, 3.9, 3.8, 2.8, 3.8, 3.5], # Festive
    [3.7, 3.1, 2.7, 3.2, 3.8, 3.9, 3.6], # HappenMovie
 #. Mon.  Tue. Wed. Thu. Fri. Sat. Sun.   
])


# ------ Provinces of Oceania --------
po_theaters = ['fishy','waterpark','aquasee','deepblue','movierain','endlesswatch']
po_rating = np.array([
    [4.1, 4.9, 4.9, 4.3, 4.1, 4. , 4.9], # Fishy
    [4.8, 4.3, 4.9, 4.5, 4.4, 4.1, 4.3], # WaterPark
    [4.4, 4.8, 4.6, 4.5, 4.4, 4.5, 4. ], # AquaSee
    [4.9, 4.2, 4.7, 4.8, 4.7, 4.1, 4.6], # DeepBlue
    [4. , 4.5, 4.8, 4.7, 4.8, 4.3, 4.6], # MovieRain
    [4.7, 4.7, 4.3, 4.4, 4.3, 4.3, 4.1], # EndlessWatch
 #. Mon.  Tue. Wed. Thu. Fri. Sat. Sun.   
])


# ------ The Kingdom of Skydome --------
kos_theaters = ['skyview','moviemix','domdom','kingview','movieking','ablesee']
kos_rating = np.array([
    [5.0, 4.5, 5.0, 5.0, 5.0, 5.0, 5.0], # SkyView
    [4. , 4.1, 5.0, 5.0, 4.1, 4.3, 4.4], # MovieMix
    [5.0, 4.6, 4.6, 5.0, 5.0, 4.3, 4.4], # DomDom
    [4.2, 4.1, 4.3, 5.0, 5.0, 4.1, 4.5], # KingView
    [4.4, 4.5, 4.5, 4.5, 5.0, 4.5, 4.5], # MovieKing
    [4.6, 4.1, 4.1, 4.7, 4.7, 4.4, 4.6], # AbleSee
 #. Mon.  Tue. Wed. Thu. Fri. Sat. Sun.   
])



# ------- type the answer below this line ------- #

# %% [markdown]
# ### Question # 2:
#
# The movie studio was able to get data on how many people actually watched the movie in the given movie theaters within each country.
#
# #### Requests:
# - Create a new cell. Then write code in it to create a scatter plot by country where x-axis: customer rating; and y-axis: number of customers or people that watched the movie Thonpy
#         - Hint-1: Write the code for each of the five country separately in the same cell. Give each plot a different color. This will generate an overlay of five scatter plots
#         For example: xA=f_rating; yA=f_cust_num
#         plt.scatter(xA,yA, color='red', label='Country A') # Country A
#         plt.scatter(xB,yB, color='blue', label='Country B') # Country B
#         .
#         .
#         .
#         .
#         plt.legend(loc='upper right',bbox_to_anchor=(1.6,1))  # <-- use this line to plot legents
#         plt.show()
#         - Hint-2: Make sure the x,y axes and the plot title are labeled
#         - Hint-3: set 'alpha=0.5' to make the dots transperant
#
#
# - In a new cell, write code to plot the same data in a scatter plot again individually for each country. Arrange the five plots in a grid of 2 rows and three columns.
#         - Hint-1: Use subplot
#         fig = plt.figure(figsize=(15,5))
#         plt.subplot(2,3,1)
#         ... 1st figure here ...
#         plt.subplot(2,3,2)
#         ... 2nd figure here ...
#         .
#         .
#         . and so on ...
#         - Hint-2: For spacing between subplots use:
#         plt.tight_layout()
#         - Hint-3: Make sure the x,y axes and the plot title are labeled
#
#
# - In a new cell, write code to plot the total number of customers or people that watch the movie by country.
#         - Hint-1: Sum all the number of customers from the array such as 'f_cust_num'
#         Then, add these five numbers, one for each country to a new list 'total_cust_num'
#         - Hint-2: Use bar plot to plot the data. Where, x-axis has country name, y-axis has total customer number
#
# Print all answers to output
#
# [Note: Create new variables of your choice as needed.]

# %%
np.random.seed(1) # Set random seed = 1 to get same numbers

# Number of customers that went to movie theaters to watch 'Thonpy'
# (in thousands)
f_cust_num = 1000*np.random.random((6,7)).round(2)
pol_cust_num = 1000*np.random.random((6,7)).round(2)
r_cust_num = 1000*np.random.random((6,7)).round(2)
po_cust_num = 1000*np.random.random((6,7)).round(2)
kos_cust_num = 1000*np.random.random((6,7)).round(2)

# ------- type the answer below this line ------- #

# %% [markdown]
# ### Question #3
#
# Create a final figure with four subplots (2x2 grid), such that it has one of each:
# - a line plot
# - a bar plot
# - a scatter plot
# - a heatmap
#
# Please feel free to choose any data from above to create these four plots.
# Make sure that axes are labeled and the plot has a title
#
#
# [Note: Create new variables of your choice as needed.]

# %%
# ------- type the answer below this line ------- #

# %% [markdown]
# ### ////////////////////////////////////////////////////////////////////////////////////////////////////////
# ### ////////////////////////////////////////////////////////////////////////////////////////////////////////
# ### For practice, please try the questions above before looking at the answers below
# ### ////////////////////////////////////////////////////////////////////////////////////////////////////////
# ### ////////////////////////////////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# # Answers
# [Note: There may be different ways to answer the same question. Therefore, it is okay if the answers vary and sometimes do not match exactly.]

# %% [markdown]
# ### Question 0:
#
# - In a new cell, create a line plot using x, y
# - In a new cell, create a bar plot using xb, yb
# - In a new cell, create a scatter plot using xs, ys
# - In a new cell, create a histogram using xh
#
# Note: Add labels to both x-axis, y-axis and the plot title

# %%
# Data for line plot
x = np.linspace(0,100, 50,1)
y = x**2

# Data for bar plot
xb = ['A', 'B', 'C', 'D', 'E']
yb = [1000, 5000, 2345, 4905, 200]

# Data for scatter plot
xs = np.linspace(0,50,50)
ys = np.random.random(50)

# Data for histogram
xh = np.random.normal(0,0.25,500)

# %%
# ------- type the answer below this line ------- #

# Answer #1:
plt.plot(x, y, color='red')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Line plot')
plt.show()

# %%
# ------- type the answer below this line ------- #

# Answer #2:
plt.bar(xb, yb, color='blue')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Bar plot')
plt.show()

# %%
# ------- type the answer below this line ------- #

# Answer #3:
plt.scatter(xs, ys, color='orange')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Scatter plot')
plt.show()

# %%
# ------- type the answer below this line ------- #

# Answer #4:
plt.hist(xh, color='grey')
plt.xlabel('x-axis')
plt.ylabel('count')
plt.title('Histogram')
plt.show()

# %% [markdown]
# ### Question 1:
#
# #### Story
# A new movie 'Thonpy' was released this week. It was a box office hit!!! Entire crew of the movie studio are very happy and would like to visualize their success in the world.
#
# Let's help them out!
#
# #### Request:
# - In a new cell, create a bar plot for movie revenue by country
#         - Hint: To rotate the x-axis labels by 90 degrees type:
#         plt.xticks(rotation=90)
# - In a new cell, combine customer ratings for all countries into a single array and plot histogram
#         - Hint-1: Combine the five 6x7 arrays into a single array of shape 30x7. Store this in variable 'ratings'.
#         - Hint-2: Then use np.ndarray.flatten(ratings) to flattent the array to (210,) to plot histogram
# - In new cell, Create a heatmap for customer ratings in each country.
#         - Hint-1: To plot heatmap:
#         plt.imshow(f_rating)
#         plt.colorbar()
#
#         - Hint-2: Use subplot
#         fig = plt.figure(figsize=(15,5))
#         plt.subplot(2,3,1)
#         ... 1st figure here ...
#         plt.subplot(2,3,2)
#         ... 2nd figure here ...
#         .
#         .
#         . and so on ...
#         - Hint-4: For spacing between subplots use:
#         plt.tight_layout()
#         - Hint-3: Make sure the x,y axes and the plot title are labeled
#
#
# - In a new cell, plot the average customer rating by country
#         - Hint-1: To get an average of f_rating: np.mean(f_rating)
#         - Hint-2: Store the average rating for each country in a list 'avg_rating'
#         - Hint-3: Then use plt.bar(x,y) to plot 'countries' and the calculated average rating
#
#
# <b>Important:</b> For each plot make sure x-axis, y-axis are labeled and a title is added to each plot
#
# [Note: Create new variables of your choice as needed.]

# %%
# Countries where the movie was released
countries = ['Floweria', 'Public of Land', 'Restandris', 'Provinces of Oceania', 'The Kingdom of Skydome']

# Revenue in millions
movie_revenue = [1000, 3577, 469, 1212, 9879]

# Customer rating 1(low) --> 5(high)
# ------ Floweria --------
f_theaters = ['sunglow','superpetal','soilplant','funlily','actionacactus','rosered']
f_rating = np.array([
    [4.7, 5.0, 4.9, 4.8, 4.7, 5.0, 4.6], # SunGlow
    [3.6, 3.3, 3.2, 3.0, 3.4, 4.0, 3.2], # SuperPetal
    [4.0, 5.0, 5.0, 4.8, 4.7, 5.0, 4.6], # SoilPlant
    [4.0, 3.9, 3.8, 3.8, 3.7, 4.1, 3.4], # FunLily
    [4.4, 4.5, 4.4, 4.6, 4.5, 4.8, 4.3], # ActionCactus
    [1.4, 2.5, 1.5, 2.1, 1.7, 2.5, 1.0], # RoseRed
 #. Mon.  Tue. Wed. Thu. Fri. Sat. Sun.   
])

# ------ Public of Land --------
pol_theaters = ['landing','sandland','laland','stonemuse','rapland','tresly']
pol_rating = np.array([
    [4.4, 4.9, 4.6, 4.9, 4.1, 4.3, 4.1], # LandIng
    [4.7, 5. , 4.9, 4.3, 4.8, 4.7, 4.6], # SandLand
    [4.6, 4.3, 4.9, 4.1, 4.7, 4.9, 4.7], # LaLand
    [4.6, 4.3, 4.2, 4.4, 4.3, 4.6, 4.6], # StoneMuse
    [4.5, 5. , 4.2, 4.2, 4.3, 4.1, 4.6], # RapLand
    [4.5, 4.6, 4.4, 4.2, 4.6, 4.6, 4.1], # Tresly
 #. Mon.  Tue. Wed. Thu. Fri. Sat. Sun.   
])


# ------ Restandris --------
r_theaters = ['restmovie','andmovie','movielax','tranbie','festive','happenmovie']
r_rating = np.array([
    [3.1, 3.4, 3.8, 3. , 3.6, 3.9, 3.8], # RestMovie
    [3.3, 3.8, 3.9, 3.9, 3.5, 3.8, 3.3], # AndMovie
    [3.5, 4. , 3.9, 3.1, 3.7, 3.2, 3.3], # Movielax
    [3.9, 3.4, 3.3, 3.2, 3.6, 3.8, 3.2], # Tranbie
    [3.3, 2.5, 3.9, 3.8, 2.8, 3.8, 3.5], # Festive
    [3.7, 3.1, 2.7, 3.2, 3.8, 3.9, 3.6], # HappenMovie
 #. Mon.  Tue. Wed. Thu. Fri. Sat. Sun.   
])


# ------ Provinces of Oceania --------
po_theaters = ['fishy','waterpark','aquasee','deepblue','movierain','endlesswatch']
po_rating = np.array([
    [4.1, 4.9, 4.9, 4.3, 4.1, 4. , 4.9], # Fishy
    [4.8, 4.3, 4.9, 4.5, 4.4, 4.1, 4.3], # WaterPark
    [4.4, 4.8, 4.6, 4.5, 4.4, 4.5, 4. ], # AquaSee
    [4.9, 4.2, 4.7, 4.8, 4.7, 4.1, 4.6], # DeepBlue
    [4. , 4.5, 4.8, 4.7, 4.8, 4.3, 4.6], # MovieRain
    [4.7, 4.7, 4.3, 4.4, 4.3, 4.3, 4.1], # EndlessWatch
 #. Mon.  Tue. Wed. Thu. Fri. Sat. Sun.   
])


# ------ The Kingdom of Skydome --------
kos_theaters = ['skyview','moviemix','domdom','kingview','movieking','ablesee']
kos_rating = np.array([
    [5.0, 4.5, 5.0, 5.0, 5.0, 5.0, 5.0], # SkyView
    [4. , 4.1, 5.0, 5.0, 4.1, 4.3, 4.4], # MovieMix
    [5.0, 4.6, 4.6, 5.0, 5.0, 4.3, 4.4], # DomDom
    [4.2, 4.1, 4.3, 5.0, 5.0, 4.1, 4.5], # KingView
    [4.4, 4.5, 4.5, 4.5, 5.0, 4.5, 4.5], # MovieKing
    [4.6, 4.1, 4.1, 4.7, 4.7, 4.4, 4.6], # AbleSee
 #. Mon.  Tue. Wed. Thu. Fri. Sat. Sun.   
])

# %%
# ------- type the answer below this line ------- #
# Answer # 1:
plt.bar(countries, movie_revenue)
plt.xlabel('Country')
plt.ylabel('Movie Revenue')
plt.title('Box office revenue for movie Thonpy')
plt.xticks(rotation=90)
plt.show()

# %%
# ------- type the answer below this line ------- #
# Answer # 2:
# Combine all 6x7 arrays into a single array of shape 30,7
ratings = np.vstack((f_rating,pol_rating,r_rating,po_rating,kos_rating))
# Flatten array
ratings = np.ndarray.flatten(ratings)
plt.hist(ratings)
plt.xlabel('Customer Ratings')
plt.ylabel('Count')
plt.title('Distribution of customer ratings for movie Thonpy')
plt.show()

# %%
# ------- type the answer below this line ------- #
# Answer # 3:

fig = plt.figure(figsize=(15,5))

plt.subplot(2,3,1)
plt.imshow(f_rating)
plt.colorbar()
plt.xlabel('Rating: Day_of_week')
plt.ylabel('Rating: Movie_Theater')
plt.title('Floweria')

plt.subplot(2,3,2)
plt.imshow(pol_rating)
plt.colorbar()
plt.xlabel('Rating: Day_of_week')
plt.ylabel('Rating: Movie_Theater')
plt.title('Public of Land')

plt.subplot(2,3,3)
plt.imshow(r_rating)
plt.colorbar()
plt.xlabel('Rating: Day_of_week')
plt.ylabel('Rating: Movie_Theater')
plt.title('Restandris')

plt.subplot(2,3,4)
plt.imshow(po_rating)
plt.colorbar()
plt.xlabel('Rating: Day_of_week')
plt.ylabel('Rating: Movie_Theater')
plt.title('Provinces of Oceania')

plt.subplot(2,3,5)
plt.imshow(kos_rating)
plt.colorbar()
plt.xlabel('Rating: Day_of_week')
plt.ylabel('Rating: Movie_Theater')
plt.title('The Kingdom of Skydome')


plt.tight_layout()
plt.show()

# %%
# ------- type the answer below this line ------- #
# Answer # 4:

# Calculate average customer rating for each country
avg_rating = [np.mean(f_rating), np.mean(pol_rating), np.mean(r_rating), np.mean(po_rating), np.mean(kos_rating)]

# Plot
plt.bar(countries, avg_rating)
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Average customer review')
plt.title('Customer rating for movie Thonpy')
plt.show()

# %% [markdown]
# ### Question # 2:
#
# The movie studio was able to get data on how many people actually watched the movie in the given movie theaters within each country.
#
# #### Requests:
# - Create a new cell. Then write code in it to create a scatter plot by country where x-axis: customer rating; and y-axis: number of customers or people that watched the movie Thonpy
#         - Hint-1: Write the code for each of the five country separately in the same cell. Give each plot a different color. This will generate an overlay of five scatter plots
#         For example: xA=f_rating; yA=f_cust_num
#         plt.scatter(xA,yA, color='red', label='Country A') # Country A
#         plt.scatter(xB,yB, color='blue', label='Country B') # Country B
#         .
#         .
#         .
#         .
#         plt.legend(loc='upper right',bbox_to_anchor=(1.6,1))  # <-- use this line to plot legents
#         plt.show()
#         - Hint-2: Make sure the x,y axes and the plot title are labeled
#         - Hint-3: set 'alpha=0.5' to make the dots transperant
#
#
# - In a new cell, write code to plot the same data in a scatter plot again individually for each country. Arrange the five plots in a grid of 2 rows and three columns.
#         - Hint-1: Use subplot
#         fig = plt.figure(figsize=(15,5))
#         plt.subplot(2,3,1)
#         ... 1st figure here ...
#         plt.subplot(2,3,2)
#         ... 2nd figure here ...
#         .
#         .
#         . and so on ...
#         - Hint-2: For spacing between subplots use:
#         plt.tight_layout()
#         - Hint-3: Make sure the x,y axes and the plot title are labeled
#
#
# - In a new cell, write code to plot the total number of customers or people that watch the movie by country.
#         - Hint-1: Sum all the number of customers from the array such as 'f_cust_num'
#         Then, add these five numbers, one for each country to a new list 'total_cust_num'
#         - Hint-2: Use bar plot to plot the data. Where, x-axis has country name, y-axis has total customer number
#
# Print all answers to output
#
# [Note: Create new variables of your choice as needed.]

# %%
np.random.seed(1) # Set random seed = 1 to get same numbers

# Number of customers that went to movie theaters to watch 'Thonpy'
# (in thousands)
f_cust_num = 1000*np.random.random((6,7)).round(2)
pol_cust_num = 1000*np.random.random((6,7)).round(2)
r_cust_num = 1000*np.random.random((6,7)).round(2)
po_cust_num = 1000*np.random.random((6,7)).round(2)
kos_cust_num = 1000*np.random.random((6,7)).round(2)

# %%
# ------- type the answer below this line ------- #
# Answer # 1
plt.scatter(f_rating, f_cust_num, color='red', label='Floweria')
plt.scatter(pol_rating, pol_cust_num, color='blue', label='Public of Land')
plt.scatter(r_rating, r_cust_num, color='green', label='Restandris')
plt.scatter(po_rating, po_cust_num, color='orange', label='Provinces of Oceania')
plt.scatter(kos_rating, kos_cust_num, color='violet', label='The Kingdom of Skydome')
plt.xlabel('Customer Rating [1(low)--> 5(high)]')
plt.ylabel('Number of customers')
plt.title('Moviegoers for Thonpy')
plt.legend(loc='upper right',bbox_to_anchor=(1.6,1))
plt.show()

# %%
# ------- type the answer below this line ------- #
# Answer # 2:
 
fig = plt.figure(figsize=(15,5))

plt.subplot(2,3,1)
plt.scatter(f_rating, f_cust_num, color='red')
plt.xlabel('Customer Rating [1(low)--> 5(high)]')
plt.ylabel('Number of customers')
plt.title('Floweria')

plt.subplot(2,3,2)
plt.scatter(pol_rating, pol_cust_num, color='blue')
plt.xlabel('Customer Rating [1(low)--> 5(high)]')
plt.ylabel('Number of customers')
plt.title('Public of Land')

plt.subplot(2,3,3)
plt.scatter(r_rating, r_cust_num, color='green')
plt.xlabel('Customer Rating [1(low)--> 5(high)]')
plt.ylabel('Number of customers')
plt.title('Restandris')

plt.subplot(2,3,4)
plt.scatter(po_rating, po_cust_num, color='orange')
plt.xlabel('Customer Rating [1(low)--> 5(high)]')
plt.ylabel('Number of customers')
plt.title('Provinces of Oceania')

plt.subplot(2,3,5)
plt.scatter(kos_rating, kos_cust_num, color='violet')
plt.xlabel('Customer Rating [1(low)--> 5(high)]')
plt.ylabel('Number of customers')
plt.title('The Kingdom of Skydome')

#plt.suptitle('Moviegoers for Thonpy')
plt.tight_layout()
plt.show()

# %%
# ------- type the answer below this line ------- #
# Answer # 3

# Calculate the sum
f_total = np.sum(f_cust_num)
pol_total = np.sum(pol_cust_num)
r_total = np.sum(r_cust_num)
po_total = np.sum(po_cust_num)
kos_total = np.sum(kos_cust_num)

# Put the sum of each country a list
# IMPORTANT: The order has to be the same as in 'countries'
total_watchers = [f_total, pol_total, r_total, po_total, kos_total]

# Plot
plt.bar(countries, total_watchers)
plt.xlabel('Country')
plt.ylabel('Total customers')
plt.xticks(rotation=90)
plt.title('Customers that watch Thonpy')
plt.show()

# %% [markdown]
# ### Question #3
#
# Create a final figure with four subplots (2x2 grid), such that it has one of each:
# - a line plot
# - a bar plot
# - a scatter plot
# - a heatmap
#
# Please feel free to choose any data from above to create these four plots.
# Make sure that axes are labeled and the plot has a title
#
#
# [Note: Create new variables of your choice as needed.]

# %%
# ------- type the answer below this line ------- #

fig = plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
# Get data
weekday = np.arange(1,8)
cust_num = np.vstack((f_cust_num,pol_cust_num,r_cust_num,po_cust_num,kos_cust_num))
moviegoers_by_weekday = np.sum(cust_num, axis=0)
# plot
plt.plot(weekday, moviegoers_by_weekday, color='orange')
plt.xlabel('Day of a week (1:Monday --> 7:Sunday)')
plt.ylabel('Worldwide count')
plt.title('Moviegoers for the movie Thonpy in a week')


plt.subplot(2,2,2)
plt.scatter(f_rating, f_cust_num, color='red', label='Floweria')
plt.scatter(pol_rating, pol_cust_num, color='blue', label='Public of Land')
plt.scatter(r_rating, r_cust_num, color='green', label='Restandris')
plt.scatter(po_rating, po_cust_num, color='orange', label='Provinces of Oceania')
plt.scatter(kos_rating, kos_cust_num, color='violet', label='The Kingdom of Skydome')
plt.xlabel('Customer Rating [1(low)--> 5(high)]')
plt.ylabel('Number of customers')
plt.title('Worldwide customer rating for Thonpy')
plt.legend(loc='upper right',bbox_to_anchor=(1.6,1))



plt.subplot(2,2,3)
plt.bar(countries, total_watchers)
plt.xlabel('Country')
plt.ylabel('Total customers')
plt.xticks(rotation=90)
plt.title('Customers that watch Thonpy')



plt.subplot(2,2,4)
# get data
ratings = np.vstack((f_rating,pol_rating,r_rating,po_rating,kos_rating))
plt.imshow(ratings)
plt.xlabel('Ratings: weekday')
plt.ylabel('Ratings: movie theater')
plt.title('Heatmap of customer ratings')
plt.colorbar()



plt.tight_layout()
plt.show()

# %% [markdown]
# # Congratulations on completing the exercise!

# %% [markdown]
# ### Hope you enjoyed the questions. Thank you !!!

# %% [markdown]
# #### Please like, share and subscribe to learndataa
# -<html>https://www.youtube.com/channel/UCzUpHQAfj3ulmJkTAfBtXLw/</html>

# %%
#learndataa learndataa learndataa learndataa learndataa learndataa learndataa learndataa learndataa
